# %%
# Haetaan kaikki ladattavat kaudet erikseen määritetystä tiedostosta

import csv

urls = []

# Lue csv-tiedoston sarake ilman otsikkoa ja tallenna listaan urlit
with open('LiigaKaudet.csv', encoding='utf-8') as csvfile:
    reader = csv.reader(csvfile)
    next(reader, None)
    urls = list(reader)
    
for url in urls:
    print(url)
# Out:
# ['https://www.liiga.fi/fi/tilastot/2020-2021/runkosarja/pelaajat/']
# ['https://www.liiga.fi/fi/tilastot/2019-2020/runkosarja/pelaajat/']
# ['https://www.liiga.fi/fi/tilastot/2018-2019/runkosarja/pelaajat/']

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import bs4
import requests

from bs4 import BeautifulSoup
from urllib.request import urlopen

# %%
# Kerätään tiedot webscrapperilla ja tallennetaan dataframeen

first_url = True

list_of_players = []

# Käydään yksi url-osoite kerrrallaan läpi
for url in urls:
    html = urlopen(url[0])
    soup = BeautifulSoup(html, 'lxml')

    # Sivun otsikko
    title = soup.find('title')
    title_splitted = title.string.split()
    season = title_splitted[5]
    print("Avattu: " + season)
    
    
    # Tarkista onko ensimmäinen kierros --> Luo dataframe
    if first_url:
        for all_data in soup.find_all('table', {'id': 'stats'}):
            
            # Haetaan otsikkorivi
            for headers in all_data.find_all('thead'):
                for header in headers.find_all('tr'):
                    column_names = []
                    column_names.append("Kausi")
                    for column in header.find_all('td'):
                        column_names.append(' '.join(column.text.split()))
        
        df = pd.DataFrame(columns = column_names)
        print("Luotu df: ")
        print(column_names)
    
    # Haetaan pelaajien tilastot taulukosta ja lisätään df
    for all_data in soup.find_all('table', {'id': 'stats'}):
        
        #Pelaajatilastot: kaikki pelaajat yhteen listaan
        for table_of_stats in all_data.find_all('tbody'):
            
            for stats in table_of_stats.find_all('tr'):
                player = []
                player.append(season)
                for detail in stats.find_all('td'):
                    player.append(' '.join(detail.text.split()))
                list_of_players.append(player)

                # Tallennetaan pelaajatiedot dataframeen
                df.loc[len(df)] = player
    
    print("Tallennettu kausi " + season + " dataframeen \n")
    first_url = False
# Out:
# Avattu: 2020-2021
# Luotu df:
# ['Kausi', '#', 'Nimi', 'Joukkue', 'PP', 'O', 'M', 'S', 'P', 'R', '+', '-', '±', 'YV', 'AV', 'VM', 'L', 'L%', 'A', 'A%', 'Aika']
# Tallennettu kausi 2020-2021 dataframeen
#
# Avattu: 2019-2020
# Tallennettu kausi 2019-2020 dataframeen
#
# Avattu: 2018-2019
# Tallennettu kausi 2018-2019 dataframeen

# %%
# Toinen tapa poimia tiedot dataframeen
#print(column_names)
#print(list_of_players)

# %%
# Tarkista dataframen tiedot
print(df)
print(df.dtypes)
df.head()
# Out:
#           Kausi     #                Nimi Joukkue  PP   O   M   S   P   R  \
# 0     2020-2021    1.     Kontiola, Petri     HPK  KH  55  14  41  55  54
# 1     2020-2021    2.     Audette, Daniel   Lukko  KH  60  13  37  50  34
# 2     2020-2021    3.       Kestner, Josh     TPS  VH  59  24  25  49  20
# 3     2020-2021    4.       Oksanen, Ahti  KooKoo  VH  53  22  26  48  20
# 4     2020-2021    5.        Press, Robin   Lukko  OP  58  17  31  48  28
# ...         ...   ...                 ...     ...  ..  ..  ..  ..  ..  ..
# 1589  2018-2019  530.    Seppälä, Erkka *     HPK  KH  18   0   0   0   4
# 1590  2018-2019  531.  Kiviniemi, Teemu *   Ässät  OP   6   0   0   0   0
# 1591  2018-2019  532.    Salmela, Santeri  KooKoo  OP  17   0   0   0   2
# 1592  2018-2019  533.     # Saukko, Ville   Sport  OP  25   0   0   0  18
# 1593  2018-2019  534.      Generous, Matt   Ilves  OP  40   0   0   0  45
#
#       ...   -    ±  YV AV VM    L   L%     A    A%   Aika
# 0     ...  33    2   7  0  2  146  9,6  1128  53,4  19:56
# 1     ...  22   23   6  0  4  220  5,9   711  46,1  17:11
# 2     ...  34    6  12  0  9  268  9,0     0     -  16:10
# 3     ...  29   16   5  1  4  316  7,0   206  40,8  19:58
# 4     ...  32   22   9  0  5  292  5,8     0     -  24:01
# ...   ...  ..  ...  .. .. ..  ...  ...   ...   ...    ...
# 1589  ...   6   -4   0  0  0   16  0,0    62  40,3   9:13
# 1590  ...   6   -5   0  0  0    5  0,0     0     -  10:38
# 1591  ...  14   -7   0  0  0    9  0,0     0     -  12:18
# 1592  ...  19  -12   0  0  0   32  0,0     0     -  13:29
# 1593  ...  19  -15   0  0  0   47  0,0     0     -  15:06
#
# [1594 rows x 21 columns]
# Kausi      object
# #          object
# Nimi       object
# Joukkue    object
# PP         object
# O          object
# M          object
# S          object
# P          object
# R          object
# +          object
# -          object
# ±          object
# YV         object
# AV         object
# VM         object
# L          object
# L%         object
# A          object
# A%         object
# Aika       object
# dtype: object
#        Kausi   #             Nimi Joukkue  PP   O   M   S   P   R  ...   -  \
# 0  2020-2021  1.  Kontiola, Petri     HPK  KH  55  14  41  55  54  ...  33
# 1  2020-2021  2.  Audette, Daniel   Lukko  KH  60  13  37  50  34  ...  22
# 2  2020-2021  3.    Kestner, Josh     TPS  VH  59  24  25  49  20  ...  34
# 3  2020-2021  4.    Oksanen, Ahti  KooKoo  VH  53  22  26  48  20  ...  29
# 4  2020-2021  5.     Press, Robin   Lukko  OP  58  17  31  48  28  ...  32
#
#     ±  YV AV VM    L   L%     A    A%   Aika
# 0   2   7  0  2  146  9,6  1128  53,4  19:56
# 1  23   6  0  4  220  5,9   711  46,1  17:11
# 2   6  12  0  9  268  9,0     0     -  16:10
# 3  16   5  1  4  316  7,0   206  40,8  19:58
# 4  22   9  0  5  292  5,8     0     -  24:01
#
# [5 rows x 21 columns]

# %%
# Muutetaan sarakkeiden nimet
df.rename(columns= {'#': 'Pistepörssi_sijoitus', 'PP' : 'Pelipaikka', '+': 'Plussat', '-': 'Miinukset', '±': 'PlusMiinus', 'Aika': 'Peliaika'}, inplace=True)

# Korjataan arvoja
df['Plussat'] = df['Plussat'].replace(['-'], None)
df['Miinukset'] = df['Miinukset'].replace(['-'], None)
df['PlusMiinus'] = df['PlusMiinus'].replace(['-'], None)
#df['L%'] = df['L%'].replace([','], '.')
#df['A%'] = df['A%'].replace([','], '.')

# Muokataan tietotyyppejä
df['Joukkue'] = df['Joukkue'].astype('category')
df['Pelipaikka'] = df['Pelipaikka'].astype('category')
df['O'] = df['O'].astype('int64')
df['M'] = df['M'].astype('int64')
df['S'] = df['S'].astype('int64')
df['P'] = df['P'].astype('int64')
df['R'] = df['R'].astype('int64')
df['Plussat'] = df['Plussat'].astype('int64')
df['Miinukset'] = df['Miinukset'].astype('int64')
df['PlusMiinus'] = df['PlusMiinus'].astype('int64')
df['YV'] = df['YV'].astype('int64')
df['AV'] = df['AV'].astype('int64')
df['VM'] = df['VM'].astype('int64')
df['L'] = df['L'].astype('int64')
#df['L%'] = df['L%'].astype('int64')
df['A'] = df['A'].astype('int64')
#df['A%'] = df['A%'].astype('int64')

df.dtypes
# Out:
# Kausi                     object
# Pistepörssi_sijoitus      object
# Nimi                      object
# Joukkue                 category
# Pelipaikka              category
# O                          int64
# M                          int64
# S                          int64
# P                          int64
# R                          int64
# Plussat                    int64
# Miinukset                  int64
# PlusMiinus                 int64
# YV                         int64
# AV                         int64
# VM                         int64
# L                          int64
# L%                        object
# A                          int64
# A%                        object
# Peliaika                  object
# dtype: object

# %%
# Muokataan datasetin tietueita käytettävämpään muotoon 

"""
Korjauksia: L%, A%
Päättelyä: kausi, nimi, plussat, miinukset, plusmiinus, L%, A%, peliaika
"""

#Kausi
df['Kausi_jaettu'] = df['Kausi'].str.split('-')
df['Kausi_aloitus'] = df.apply(lambda row: row.Kausi_jaettu[0], axis=1)
df['Kausi_lopetus'] = df.apply(lambda row: row.Kausi_jaettu[1], axis=1)
df.drop('Kausi_jaettu', inplace=True, axis=1)

#Nimi
df['Tulokas'] = df['Nimi'].str.contains('*', regex=False)
df['Ulkomaille'] = df['Nimi'].str.contains('#', regex=False)
df['Nimi'] = df['Nimi'].map(lambda cell: cell.lstrip('#*').rstrip('aAbBcC'))

#Nimi
df['Nimi_jaettu'] = df['Nimi'].str.split(',')
df['Etunimi'] = df.apply(lambda row: row.Nimi_jaettu[1], axis=1)
df['Sukunimi'] = df.apply(lambda row: row.Nimi_jaettu[0], axis=1)
df['Koko_nimi'] = df['Sukunimi'] + ' ' + df['Etunimi']
df.drop('Nimi_jaettu', inplace=True, axis=1)
#df.drop('Nimi', inplace=True, axis=1)

#Peliaika
df['Peliaika_jaettu'] = df['Peliaika'].str.split(':')
df['Peliaika_minuutit'] = df.apply(lambda row: row.Peliaika_jaettu[0], axis=1)
#df['Peliaika_sekuntit'] = df.apply(lambda row: row.Peliaika_jaettu[1], axis=1)
df.drop('Peliaika_jaettu', inplace=True, axis=1)


df.head(40)
# Out:
#         Kausi Pistepörssi_sijoitus                  Nimi   Joukkue Pelipaikka  \
# 0   2020-2021                   1.       Kontiola, Petri       HPK         KH
# 1   2020-2021                   2.       Audette, Daniel     Lukko         KH
# 2   2020-2021                   3.         Kestner, Josh       TPS         VH
# 3   2020-2021                   4.         Oksanen, Ahti    KooKoo         VH
# 4   2020-2021                   5.          Press, Robin     Lukko         OP
# 5   2020-2021                   6.     Björninen, Hannes  Pelicans         KH
# 6   2020-2021                   7.         Suomi, Eemeli     Ilves         VH
# 7   2020-2021                   8.  Wännström, Sebastian     Ässät         OH
# 8   2020-2021                   9.        Levtchi, Anton   Tappara         OH
# 9   2020-2021                  10.    Koivistoinen, Eetu     Lukko         KH
# 10  2020-2021                  11.        Meyer, Nicolai     Ässät         VH
# 11  2020-2021                  12.           Kunyk, Cody    Kärpät         KH
# 12  2020-2021                  13.      Pärssinen, Juuso       TPS         KH
# 13  2020-2021                  14.     Kuusela, Kristian   Tappara         VH
# 14  2020-2021                  15.         Rooba, Robert       JYP         VH
# 15  2020-2021                  16.   Puustinen, Valtteri       HPK         OH
# 16  2020-2021                  17.       Zaborsky, Tomas     SaiPa         VH
# 17  2020-2021                  18.    Turkulainen, Jerry       JYP         OH
# 18  2020-2021                  19.        Eronen, Elmeri       HPK         OP
# 19  2020-2021                  20.       Skalicky, Pavol     Lukko         OH
# 20  2020-2021                  21.      Maccelli, Matias     Ilves         VH
# 21  2020-2021                  22.       Stenqvist, Jako     Ässät         OP
# 22  2020-2021                  23.      Pajuniemi, Lauri       TPS         VH
# 23  2020-2021                  24.       Cerveny, Rudolf  Pelicans         VH
# 24  2020-2021                  25.         Galló, Vilmos    KooKoo         OH
# 25  2020-2021                  26.       Ishakov, Ruslan       TPS         KH
# 26  2020-2021                  27.       Saarela, Aleksi     Lukko         VH
# 27  2020-2021                  28.          Innala, Jere       HPK         VH
# 28  2020-2021                  29.         Ikonen, Juuso       HPK         KH
# 29  2020-2021                  30.           Lasch, Ryan  Pelicans         OH
# 30  2020-2021                  31.         Platzer, Kyle    KooKoo         KH
# 31  2020-2021                  32.         Virta, Patrik   Tappara         KH
# 32  2020-2021                  33.          Kantola, Kai     KalPa         OH
# 33  2020-2021                  34.         Nurmi, Markus       TPS         OH
# 34  2020-2021                  35.      Saarijärvi, Vili     Lukko         OP
# 35  2020-2021                  36.        Sallinen, Jere      HIFK         OH
# 36  2020-2021                  37.     Kangasniemi, Iikk  Pelicans         VH
# 37  2020-2021                  38.      Broadhurst, Alex      HIFK         KH
# 38  2020-2021                  39.          Pyörälä, Mik    Kärpät         VH
# 39  2020-2021                  40.     Tuppurainen, Jani       JYP         VH
#
#      O   M   S   P   R  ...    A%  Peliaika  Kausi_aloitus  Kausi_lopetus  \
# 0   55  14  41  55  54  ...  53,4     19:56           2020           2021
# 1   60  13  37  50  34  ...  46,1     17:11           2020           2021
# 2   59  24  25  49  20  ...     -     16:10           2020           2021
# 3   53  22  26  48  20  ...  40,8     19:58           2020           2021
# 4   58  17  31  48  28  ...     -     24:01           2020           2021
# 5   49  16  31  47  49  ...  62,6     20:39           2020           2021
# 6   52  11  36  47  38  ...  36,4     20:10           2020           2021
# 7   58  33  13  46  33  ...  50,0     18:44           2020           2021
# 8   49  16  29  45  20  ...  48,1     17:19           2020           2021
# 9   59  24  20  44  24  ...  57,3     17:26           2020           2021
# 10  53  16  26  42   4  ...  57,1     17:57           2020           2021
# 11  53  15  27  42  26  ...  49,9     19:56           2020           2021
# 12  55   8  34  42  36  ...  47,2     17:10           2020           2021
# 13  49   6  36  42  24  ...  40,0     18:48           2020           2021
# 14  59  30  11  41  54  ...   0,0     19:07           2020           2021
# 15  51  21  20  41  14  ...     -     18:03           2020           2021
# 16  53  15  26  41  18  ...  50,0     21:04           2020           2021
# 17  57  15  25  40  36  ...  37,5     19:07           2020           2021
# 18  55   9  31  40  26  ...     -     24:23           2020           2021
# 19  55  20  19  39  30  ...  58,8     15:30           2020           2021
# 20  51  15  24  39  20  ...  37,5     16:03           2020           2021
# 21  57  10  29  39  22  ...     -     19:59           2020           2021
# 22  48  22  16  38  38  ...     -     16:56           2020           2021
# 23  56  21  17  38  46  ...  41,4     18:16           2020           2021
# 24  55  20  18  38  38  ...  25,0     17:13           2020           2021
# 25  54  10  28  38  24  ...  41,9     15:28           2020           2021
# 26  43  23  14  37  22  ...  70,4     16:54           2020           2021
# 27  42  20  17  37  42  ...  33,3     20:15           2020           2021
# 28  57  13  24  37  18  ...  50,9     19:50           2020           2021
# 29  26  10  27  37   6  ...     -     19:39           2020           2021
# 30  52   9  28  37  14  ...  48,9     18:56           2020           2021
# 31  56  21  15  36  42  ...  52,3     18:36           2020           2021
# 32  57  19  17  36  38  ...  49,3     18:10           2020           2021
# 33  46  18  18  36  22  ...  51,2     17:39           2020           2021
# 34  50   9  27  36  26  ...     -     21:03           2020           2021
# 35  45  15  20  35  20  ...  40,7     19:58           2020           2021
# 36  41  11  24  35  22  ...  60,0     17:19           2020           2021
# 37  45   7  28  35  12  ...  49,8     16:38           2020           2021
# 38  56  12  22  34  32  ...  49,1     18:58           2020           2021
# 39  59  11  23  34  44  ...  33,3     17:43           2020           2021
#
#     Tulokas  Ulkomaille     Etunimi      Sukunimi             Koko_nimi  \
# 0     False       False       Petri      Kontiola       Kontiola  Petri
# 1     False       False      Daniel       Audette       Audette  Daniel
# 2     False       False        Josh       Kestner         Kestner  Josh
# 3     False       False        Ahti       Oksanen         Oksanen  Ahti
# 4     False       False       Robin         Press          Press  Robin
# 5     False       False      Hannes     Björninen     Björninen  Hannes
# 6     False       False      Eemeli         Suomi         Suomi  Eemeli
# 7     False       False   Sebastian     Wännström  Wännström  Sebastian
# 8     False       False       Anton       Levtchi        Levtchi  Anton
# 9     False       False        Eetu  Koivistoinen    Koivistoinen  Eetu
# 10    False       False     Nicolai         Meyer        Meyer  Nicolai
# 11    False       False        Cody         Kunyk           Kunyk  Cody
# 12    False       False       Juuso     Pärssinen      Pärssinen  Juuso
# 13    False       False    Kristian       Kuusela     Kuusela  Kristian
# 14    False       False      Robert         Rooba         Rooba  Robert
# 15    False       False    Valtteri     Puustinen   Puustinen  Valtteri
# 16    False       False       Tomas      Zaborsky       Zaborsky  Tomas
# 17    False       False       Jerry   Turkulainen    Turkulainen  Jerry
# 18    False       False      Elmeri        Eronen        Eronen  Elmeri
# 19    False       False       Pavol      Skalicky       Skalicky  Pavol
# 20    False       False      Matias      Maccelli      Maccelli  Matias
# 21    False       False        Jako     Stenqvist       Stenqvist  Jako
# 22    False       False       Lauri     Pajuniemi      Pajuniemi  Lauri
# 23    False       False      Rudolf       Cerveny       Cerveny  Rudolf
# 24    False       False      Vilmos         Galló         Galló  Vilmos
# 25    False       False      Ruslan       Ishakov       Ishakov  Ruslan
# 26    False       False      Aleksi       Saarela       Saarela  Aleksi
# 27    False       False        Jere        Innala          Innala  Jere
# 28    False       False       Juuso        Ikonen         Ikonen  Juuso
# 29    False        True        Ryan         Lasch           Lasch  Ryan
# 30    False       False        Kyle       Platzer         Platzer  Kyle
# 31    False       False      Patrik         Virta         Virta  Patrik
# 32    False       False         Kai       Kantola          Kantola  Kai
# 33    False       False      Markus         Nurmi         Nurmi  Markus
# 34    False       False        Vili    Saarijärvi      Saarijärvi  Vili
# 35    False       False        Jere      Sallinen        Sallinen  Jere
# 36    False       False        Iikk   Kangasniemi     Kangasniemi  Iikk
# 37    False       False        Alex    Broadhurst      Broadhurst  Alex
# 38    False       False         Mik       Pyörälä          Pyörälä  Mik
# 39    False       False        Jani   Tuppurainen     Tuppurainen  Jani
#
#    Peliaika_minuutit
# 0                 19
# 1                 17
# 2                 16
# 3                 19
# 4                 24
# 5                 20
# 6                 20
# 7                 18
# 8                 17
# 9                 17
# 10                17
# 11                19
# 12                17
# 13                18
# 14                19
# 15                18
# 16                21
# 17                19
# 18                24
# 19                15
# 20                16
# 21                19
# 22                16
# 23                18
# 24                17
# 25                15
# 26                16
# 27                20
# 28                19
# 29                19
# 30                18
# 31                18
# 32                18
# 33                17
# 34                21
# 35                19
# 36                17
# 37                16
# 38                18
# 39                17
#
# [40 rows x 29 columns]

# %%
# Tallennetaan datasetti csv-tiedostoon (tarvittaessa vanhan korvaaminen)

# %%
df.groupby(['Ulkomaille', 'Kausi']).count()

# %%
df.groupby(['Ulkomaille', 'Kausi']).mean()
