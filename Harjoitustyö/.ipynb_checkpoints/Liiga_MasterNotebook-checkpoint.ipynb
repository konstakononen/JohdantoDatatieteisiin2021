# %% [raw]
# Tästä ajetaan järjestyksessä kaikki tarvittavat notebookit.

# %%
# Liiga_GetPlayersStatsBySeason

# %run Liiga_GetPlayersStatsBySeason.ipynb
# Out:
# Aloitettu: Liiga_GetPlayersStatsBySeason
#
# Ladattavat kaudet:
# ['https://www.liiga.fi/fi/tilastot/2020-2021/runkosarja/pelaajat/']
# ['https://www.liiga.fi/fi/tilastot/2019-2020/runkosarja/pelaajat/']
# ['https://www.liiga.fi/fi/tilastot/2018-2019/runkosarja/pelaajat/']
#
# Avattu: 2020-2021
# Luotu df:
# ['Kausi', 'Linkki', '#', 'Nimi', 'Joukkue', 'PP', 'O', 'M', 'S', 'P', 'R', '+', '-', '±', 'YV', 'AV', 'VM', 'L', 'L%', 'A', 'A%', 'Aika']
# Tallennettu kausi 2020-2021 dataframeen
#
# Avattu: 2019-2020
# Tallennettu kausi 2019-2020 dataframeen
#
# Avattu: 2018-2019
# Tallennettu kausi 2018-2019 dataframeen
#
# DataFrame:
#
#           Kausi                                 Linkki     #  \
# 0     2020-2021   /fi/pelaajat/24540847/kontiola-petri    1.
# 1     2020-2021   /fi/pelaajat/60453964/audette-daniel    2.
# 2     2020-2021     /fi/pelaajat/60455488/kestner-josh    3.
# 3     2020-2021     /fi/pelaajat/23770029/oksanen-ahti    4.
# ...

# %%
# Liiga_GetPlayerInformation

# %run Liiga_GetPlayerInformation.ipynb
# Out:
# Aloitettu: GetPlayerInformation
#
# Aloitetaan tietojen haku:
# 2021-04-29 12:51:05.199994
# Haettavia pelaajia:
# 879
#
# Tallennettu: Kontiola, Petri dataframeen.
# https://www.liiga.fi/fi/pelaajat/24540847/kontiola-petri
# ['24540847', 'Kontiola, Petri', 'HPK', 'Keskushyökkääjä', '4.10.1984', 'FIN', 'Seinäjoki, FIN', '36', '182', '90', 'R']
#
# Tallennettu: Audette, Daniel dataframeen.
# https://www.liiga.fi/fi/pelaajat/60453964/audette-daniel
# ['60453964', 'Audette, Daniel', 'Lukko', 'Keskushyökkääjä', '5.6.1996', 'CAN', 'Blainville, QC, CAN', '24', '175', '77', 'L']
#
# Tallennettu: Kestner, Josh dataframeen.
# https://www.liiga.fi/fi/pelaajat/60455488/kestner-josh
# ['60455488', 'Kestner, Josh', 'TPS', 'Vasen laitahyökkääjä', '8.11.1993', 'USA', 'Huntsville, AL, USA', '27', '185', '79', 'R']
#
# Tallennettu: Oksanen, Ahti dataframeen.
# https://www.liiga.fi/fi/pelaajat/23770029/oksanen-ahti
# ...

# %%
# Liiga_GetPlayersSalariesBySeason

# %run Liiga_GetPlayersSalariesBySeason.ipynb
# Out:
# Aloitettu: GetPlayersSalariesBySeason
#
# ﻿Kausi           object
# Joukkue          object
# Kokonaistulot    object
# Ansiotulot       object
# Pääomatulot      object
# Koko_nimi        object
# dtype: object
#
# Tallennettu PlayersSalaries_by_Season.csv
#
# Suoritettu PlayersSalaries_by_Season

# %%
# Liiga_CombineTables

# %run Liiga_CombineTables.ipynb
# Out:
# Aloitettu: CombineTables
#
# Taulut yhdistetty ja uusi dataset luotu.
#
# Uusi datasetti:
#
#           Kausi                                 Linkki  Pistepörssi_sijoitus  \
# 0     2020-2021   /fi/pelaajat/24540847/kontiola-petri                   1.0
# 1     2020-2021   /fi/pelaajat/60453964/audette-daniel                   2.0
# 2     2020-2021     /fi/pelaajat/60455488/kestner-josh                   3.0
# 3     2020-2021     /fi/pelaajat/23770029/oksanen-ahti                   4.0
# 4     2020-2021      /fi/pelaajat/60348444/press-robin                   5.0
# ...         ...                                    ...                   ...
# 1589  2018-2019    /fi/pelaajat/30013384/seppala-erkka                 530.0
# 1590  2018-2019  /fi/pelaajat/30361793/kiviniemi-teemu                 531.0
# 1591  2018-2019  /fi/pelaajat/30870187/salmela-santeri                 532.0
# 1592  2018-2019     /fi/pelaajat/23217870/saukko-ville                 533.0
# ...

# %%
# Liiga_MachineLearning

# %run Liiga_MachineLearning.ipynb
# Out:
# Aloitettu: MachineLearning
#
# Luodaan datasetistä ML_df, jota voidaan muokkailla tulevissa kohdissa.
#
# Kausi                     object
# Linkki                    object
# Pistepörssi_sijoitus     float64
# Nimi                      object
# Joukkue                   object
# Pelipaikka                object
# O                          int64
# M                          int64
# S                          int64
# P                          int64
# R                          int64
# Plussat                    int64
# Miinukset                  int64
# PlusMiinus                 int64
# YV                         int64
# AV                         int64
# VM                         int64
# L                          int64
# L%                        object
# A                          int64
# A%                        object
# Peliaika                  object
# Kausi_aloitus              int64
# Kausi_lopetus              int64
# Tulokas                     bool
# ...
